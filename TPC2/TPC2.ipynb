# %%
import random

print("   MENU   ")
print("1. MODALIDADE COMPUTADOR")
print("2. MODALIDADE UTILIZADOR")

opc_menu=int(input("Escolha uma modalidade"))
num_tentativa=0

if opc_menu==1:
    Num_do_pc = ( random.randrange(1,101))

    print("Adivinha o número escolhido pelo PC")

    Num_escolhido= int(input("insira um número"))

    while(Num_escolhido!= Num_do_pc ):
        if(Num_escolhido>Num_do_pc):
            print("O número escolhido é menor. TENTE OUTRA VEZ!")
            Num_escolhido=int(input())

        elif(Num_escolhido<Num_do_pc):
            print("O número que pensei é maior. TENTE OUTRA VEZ")
            Num_escolhido=int(input())
        
        num_tentativa= num_tentativa +1

    print("ACERTOU", Num_escolhido, "COM", num_tentativa, "TENTATIVAS")


elif opc_menu == 2:
    print("Pense num número de 1 a 100")
    Num_do_utilizador = int(input())
    Num_selecionado_pc = (random.randrange(1,101))
    print("O computador selecionou o", Num_selecionado_pc)

    while(Num_selecionado_pc!=Num_do_utilizador):
        if(Num_selecionado_pc>Num_do_utilizador):
            print("O número que o computador pensou é maior")
            Num_selecionado_pc=(random.randrange(1,Num_selecionado_pc))
            print("Novo número selecionado", Num_selecionado_pc)

        elif(Num_selecionado_pc<Num_do_utilizador):
            print("O número que o computador pensou é menor")
            Num_selecionado_pc=(random.randrange(Num_selecionado_pc,101))
            print("Novo número escolhido", Num_selecionado_pc)

        num_tentativa= num_tentativa +1


print("ACERTOU",Num_selecionado_pc, "COM", num_tentativa, "TENTATIVAS")
# Out:
#    MENU
# 1. MODALIDADE COMPUTADOR
# 2. MODALIDADE UTILIZADOR
# Pense num número de 1 a 100
# O computador selecionou o 59
# O número que o computador pensou é maior
# Novo número selecionado 54
# O número que o computador pensou é menor
# Novo número escolhido 80
# O número que o computador pensou é maior
# Novo número selecionado 14
# O número que o computador pensou é menor
# Novo número escolhido 56
# O número que o computador pensou é maior
# Novo número selecionado 4
# O número que o computador pensou é menor
# Novo número escolhido 22
# O número que o computador pensou é menor
# Novo número escolhido 70
# O número que o computador pensou é maior
# Novo número selecionado 42
# O número que o computador pensou é menor
# Novo número escolhido 50
# O número que o computador pensou é menor
# Novo número escolhido 77
# O número que o computador pensou é maior
# Novo número selecionado 22
# O número que o computador pensou é menor
# Novo número escolhido 66
# ...
